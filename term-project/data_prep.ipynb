# %%
from IPython.display import display, HTML

import pandas as pd

# %%
columns = ['ReceiptId', 'ItemName', 'Lv1Catagory', 'Lv2Catagory',
           'Lv3Catagory', 'Lv4Catagory', 'Lv5Catagory', 'Lv6Catagory',
           'Brand', 'VendorName', 'Price', 'Qty', 'Time', 'Date',
           'StoreName', 'StoreCategory', 'CompanyName', 'AccountNum']
df = pd.read_csv('transaction_fact.csv', names=columns, header=None)
display(df.head())
display(df.info())
# Out:
# /Users/far/.pyenv/versions/miniconda3-4.3.30/envs/senior-proj-ai/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (17) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          ReceiptId                                  ItemName Lv1Catagory  \
# 0  2022102-1087458  F9E300th1.8M 3-WaySurgeProtector1.8m:490         ALL
# 1  2020101-1105832  F9E300th1.8M 3-WaySurgeProtector1.8m:490         ALL
# 2  2020101-1021987  F9E300th1.8M 3-WaySurgeProtector1.8m:490         ALL
# 3  2020101-1080992  F9E300th1.8M 3-WaySurgeProtector1.8m:490         ALL
# 4  2020103-1040876  F9E300th1.8M 3-WaySurgeProtector1.8m:490         ALL
#
#           Lv2Catagory                      Lv3Catagory  \
# 0  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# 1  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# 2  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# ...

# %%
df = df[['ReceiptId', 'Lv2Catagory', 'Lv3Catagory', 'Qty', 'StoreName', 'Date', 'AccountNum']]
df = df[df['StoreName'] == 'PM 4PM']
display(df)
# Out:
#                ReceiptId         Lv2Catagory                      Lv3Catagory  \
# 1        2020101-1105832  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# 2        2020101-1021987  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# 3        2020101-1080992  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# 4        2020103-1040876  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# 5        2020101-1071109  40000 - LIFESTYLES  42000 - IT & GADGET ACCESSORIES
# ...                  ...                 ...                              ...
# 1192224  2020104-1076796  40000 - LIFESTYLES               41000 - STATIONERY
# 1192226  2020103-1136692  40000 - LIFESTYLES               41000 - STATIONERY
# 1192227  2020104-1071877  40000 - LIFESTYLES               41000 - STATIONERY
# 1192231  2020103-1126480  40000 - LIFESTYLES               41000 - STATIONERY
# 1192234  2020101-1133044  40000 - LIFESTYLES               41000 - STATIONERY
#
# ...

# %%
df.to_csv('transaction.csv', index=False)
