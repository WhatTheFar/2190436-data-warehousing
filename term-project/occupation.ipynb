# %%
import pandas as pd

# %%
df = pd.read_csv('member_occupation.csv')
df
# Out:
# /Users/far/.pyenv/versions/miniconda3-4.3.30/envs/spec-top-econ-data-vis/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        AccountNumber           Occupation
# 0         9200131414                  NaN
# 1         0000059631  Ergonomics Engineer
# 2         9200044322                  NaN
# 3        01101504019                  NaN
# 4        02101300055                  NaN
# ...              ...                  ...
# 640237    9200321206                  NaN
# 640238    9203000001                  NaN
# 640239    9200363253                  NaN
# 640240    9200363230                  NaN
# 640241    9200362783                  NaN
#
# [640242 rows x 2 columns]

# %%
df['Occupation'].fillna('NULL').to_csv('occupation.csv', header=False, index=False)

# %%
with open('occupation.csv', 'r') as file:
    data = file.read().replace('\n', ' ')
    
word_list = data.lower().split()

# %%
from collections import Counter

Counter(word_list).most_common()
# Out:
# [('null', 541295),
#  ('manager', 11928),
#  ('engineer', 7400),
#  ('senior', 5323),
#  ('analyst', 5054),
#  ('assistant', 4080),
#  ('director', 2810),
#  ('coordinator', 2656),
#  ('administrator', 2521),
#  ('associate', 2376),
#  ('specialist', 2289),
#  ('vp', 2219),
#  ('sales', 2022),
#  ('area', 1937),
#  ('designer', 1850),
#  ('supervisor', 1791),
#  ('quality', 1748),
#  ('account', 1666),
#  ('superintendent', 1429),
#  ('systems', 1401),
#  ('officer', 1309),
#  ('service', 1304),
#  ('project', 1272),
#  ('executive', 1211),
#  ('business', 1207),
#  ('product', 1185),
#  ('staff', 1100),
#  ('manufacturing', 1045),
#  ('development', 1024),
#  ('clerk', 1017),
#  ('lead', 1008),
#  ('representative', 938),
#  ('accountant', 927),
#  ('agent', 926),
#  ('team', 910),
#  ('relations', 907),
#  ('planner', 828),
#  ('chief', 827),
#  ('technician', 813),
#  ('production', 788),
#  ('support', 777),
#  ('leader', 764),
#  ('general', 760),
#  ('marketing', 748),
# ...
